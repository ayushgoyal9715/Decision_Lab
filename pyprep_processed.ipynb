# %%
import mne
from pyprep.prep_pipeline import PrepPipeline
import numpy as np
import glob

# %%
def read_extract(file_path):
    raw=mne.io.read_raw_edf(file_path,preload=True)
    
    montage_channels = ['T4', 'A2', 'C3', 'C4', 'A1', 'T3', 'O1', 'T5', 'O2', 
                    'F8', 'T6', 'FZ', 'FP2', 'F7', 'FP1', 'CZ']
    
    raw.pick_channels(montage_channels)
    
    channel_positions = np.array([
    [5.18e-15, -84.5, -8.85],  # T4
    [3.68e-15, -60.1, -60.1],  # A2
    [3.87e-15, 63.2, 56.9],    # C3
    [-3.87e-15, -63.2, 56.9],  # C4
    [3.68e-15, 60.1, -60.1],   # A1
    [5.18e-15, 84.5, -8.85],   # T3
    [-80.8, 26.1, -4],         # O1
    [-49.9, 68.4, -7.49],      # T5
    [-80.8, -26.1, -4],        # O2
    [49.9, -68.4, -7.49],      # F8
    [-49.9, -68.4, -7.49],     # T6
    [60.7, 0, 59.5],           # FZ
    [80.8, -26.1, -4],         # FP2
    [49.9, 68.4, -7.49],       # F7
    [80.8, 26.1, -4],          # FP1
    [5.2e-15, 0, 85],          # CZ
    [57.6, 48.2, 39.9],        # F3
    [57.6, -48.1, 39.9],       # F4
    [32.9, 0, 78.4]            # FCz
    ])
    available_channels = [ch for ch in montage_channels if ch in raw.info['ch_names']]

    # Adjust positions array to match available channels
    positions_dict = dict(zip(available_channels, channel_positions))
    positions_dict = {ch: positions_dict[ch] for ch in available_channels if ch in positions_dict}
    channel_positions = np.array([positions_dict[ch] for ch in available_channels])

    # Create the montage with the updated channel positions
    montage = mne.channels.make_dig_montage(
        ch_pos=dict(zip(available_channels, channel_positions)), 
        coord_frame='head'
    )
    
    max_time = raw.times[-1]
    tmax1 = min(max_time, 600)
    tmax2 = min(max_time, 1860)
    tmin1 = min(300, max_time)
    tmin2 = min(1500, max_time)
        
    no_stress_interval = raw.copy().crop(tmin=tmin1, tmax=tmax1)
    stressed_interval = raw.copy().crop(tmin=tmin2, tmax=tmax2)
    
    # Initialize the pipeline
    prep_params = {
        'ref_chs': 'eeg',    # Reference channels, or 'average' for average reference
        'reref_chs': 'eeg',      # Channels to rereference
        'line_freqs': [50, 60],  # Frequencies to remove line noise
    }

    # Create the PREP pipeline
    try:
        # Handle the case where there are too many bad channels
        prep = PrepPipeline(no_stress_interval, prep_params, montage)
        prep.fit()

        prep1 = PrepPipeline(stressed_interval, prep_params, montage)
        prep1.fit()

        channel_names = ['FP1', 'FP2', 'F7', 'F8']
        raw1=prep.raw
        raw2=prep1.raw
        
        (raw1).pick_channels(channel_names)
        (raw2).pick_channels(channel_names)
        
        

        epochs_no_stress = mne.make_fixed_length_epochs(raw1, duration=1, overlap=0.5)
        array_no_stressed = epochs_no_stress.get_data()

        epochs_stressed = mne.make_fixed_length_epochs(raw2, duration=1, overlap=0.5)
        array_stressed = epochs_stressed.get_data()

        return array_no_stressed, array_stressed

    except OSError as e:
        print(f"OSError: {str(e)}")
        return None
    except ValueError as e:
        print(f"ValueError: {str(e)}")
        return None

# %%
files = glob.glob("EEG files folder/*.edf")

# %%
# %%capture
no_stressed_data = []
stressed_data = []

for i in files:
    result = read_extract(i)
    if result is not None:
        no_stressed, stressed = result
        no_stressed_data.append(no_stressed)
        stressed_data.append(stressed)
    else:
        print(f"Failed to process file: {i}")
# Out:
# 2024-09-23 15:28:56,800 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FP2', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6'], 'bad_all': ['T6', 'CZ', 'FP2']}
# 2024-09-23 15:28:58,360 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T3', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['T3', 'F8', 'T6', 'T4']}
# 2024-09-23 15:28:58,388 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:28:59,936 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T3', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['T3', 'F8', 'T6', 'T4']}
# 2024-09-23 15:28:59,969 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:29:01,515 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T3', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A1', 'A2', 'F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'T3', 'T6']}
# 2024-09-23 15:29:01,546 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:29:03,080 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['F7', 'T3', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A1', 'A2', 'F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'F7', 'T3', 'T6']}
# 2024-09-23 15:29:03,108 - pyprep.reference - INFO - Iterations: 4
# 2024-09-23 15:29:04,414 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T4', 'F7', 'FZ', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A1', 'A2', 'F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'F7', 'FZ', 'T3', 'T6']}
# 2024-09-23 15:29:04,443 - pyprep.reference - INFO - Iterations: 5
# 2024-09-23 15:29:05,741 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T4', 'F7', 'FZ', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'T4', 'F8', 'A1', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'F7', 'FZ', 'T3', 'T6']}
# 2024-09-23 15:29:05,742 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:29:11,647 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': [], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6', 'CZ'], 'bad_all': ['CZ', 'F8', 'T6']}
# 2024-09-23 15:29:13,483 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T3', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'T3', 'T6']}
# 2024-09-23 15:29:13,532 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:29:15,341 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T3', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'T3', 'T6']}
# 2024-09-23 15:29:15,374 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:29:17,142 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T3', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'T3', 'T6']}
# 2024-09-23 15:29:17,142 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:29:24,548 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['FZ', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['A1', 'FZ', 'CZ']}
# 2024-09-23 15:29:25,872 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'T4', 'A1', 'FZ', 'T3'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['T6'], 'bad_all': ['C4', 'T4', 'A1', 'FZ', 'T3', 'T6']}
# 2024-09-23 15:29:25,902 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:29:27,376 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'T4', 'A1', 'FZ', 'T3'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'F8', 'A1', 'FZ', 'T3', 'T6']}
# 2024-09-23 15:29:27,408 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:29:28,717 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'T4', 'A1', 'FZ', 'F7', 'T3', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'T3', 'T6']}
# 2024-09-23 15:29:28,744 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:29:30,096 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'T4', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6', 'FP2'], 'bad_all': ['C4', 'A2', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'T3', 'T6']}
# 2024-09-23 15:29:30,129 - pyprep.reference - INFO - Iterations: 4
# 2024-09-23 15:29:31,812 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'T4', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6', 'FP2'], 'bad_all': ['C4', 'A2', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'T3', 'T6']}
# 2024-09-23 15:29:31,813 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:29:37,723 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T6', 'F7'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['FP2'], 'bad_all': ['F7', 'FP1', 'T6', 'FP2']}
# 2024-09-23 15:29:39,188 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'T4', 'A1', 'FZ', 'F7', 'T3', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['C3', 'F8'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'FZ', 'F7', 'T3', 'C3', 'T6']}
# 2024-09-23 15:29:39,220 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:29:40,759 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FZ', 'FP1', 'FP2'], 'bad_by_hf_noise': ['A1', 'FZ'], 'bad_by_correlation': ['A2', 'T4', 'A1', 'FZ', 'F7', 'T3', 'T6'], 'bad_by_SNR': ['A1', 'FZ'], 'bad_by_dropout': [], 'bad_by_ransac': ['C3', 'F8'], 'bad_all': ['A2', 'FP2', 'T4', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'T3', 'T6', 'C3']}
# 2024-09-23 15:29:40,791 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:29:42,532 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FZ', 'FP1', 'FP2'], 'bad_by_hf_noise': ['A1', 'FZ'], 'bad_by_correlation': ['A2', 'T4', 'A1', 'FZ', 'F7', 'T3', 'T6'], 'bad_by_SNR': ['A1', 'FZ'], 'bad_by_dropout': [], 'bad_by_ransac': ['C3', 'F8'], 'bad_all': ['A2', 'FP2', 'T4', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'T3', 'T6', 'C3']}
# 2024-09-23 15:29:42,532 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:29:49,490 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6'], 'bad_all': ['A2', 'T6']}
# 2024-09-23 15:29:51,001 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A1', 'A2', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'T6']}
# 2024-09-23 15:29:51,029 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:29:52,536 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A1', 'A2', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'T6']}
# 2024-09-23 15:29:52,565 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:29:54,086 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A1', 'A2', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'T6']}
# 2024-09-23 15:29:54,087 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:30:00,107 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C3', 'C4', 'FZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6', 'CZ'], 'bad_all': ['C4', 'CZ', 'FZ', 'C3', 'T6']}
# 2024-09-23 15:30:01,372 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'C3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'C3', 'FP1', 'T6']}
# 2024-09-23 15:30:01,409 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:30:02,867 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'T5', 'A1', 'FZ', 'F7', 'C3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['FP1', 'T4'], 'bad_all': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'F8', 'T5', 'A1', 'FZ', 'F7', 'C3', 'FP1', 'T6']}
# 2024-09-23 15:30:02,899 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:30:04,798 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'F8', 'T5', 'A1', 'FZ', 'F7', 'C3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['FP1', 'F8', 'T4'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'T5', 'A1', 'FZ', 'F7', 'C3', 'FP1', 'T6']}
# 2024-09-23 15:30:04,798 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:30:11,515 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T6', 'FZ', 'F7'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C3', 'F8', 'CZ'], 'bad_all': ['C4', 'CZ', 'F8', 'FZ', 'F7', 'C3', 'T6']}
# 2024-09-23 15:30:15,731 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['FZ', 'FP1'], 'bad_by_correlation': [], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6', 'CZ'], 'bad_all': ['CZ', 'F8', 'FZ', 'FP1', 'T6']}
# 2024-09-23 15:30:16,932 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T4', 'T5', 'A1', 'FZ', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'CZ'], 'bad_all': ['C4', 'CZ', 'T4', 'F8', 'T5', 'A1', 'FZ', 'C3', 'T3']}
# 2024-09-23 15:30:16,960 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:30:18,471 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['FP1'], 'bad_by_correlation': ['C4', 'T4', 'FP2', 'T5', 'A1', 'FZ', 'C3', 'T3', 'FP1'], 'bad_by_SNR': ['FP1'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'CZ'], 'bad_all': ['C4', 'CZ', 'FP2', 'T4', 'F8', 'T5', 'A1', 'FZ', 'FP1', 'C3', 'T3']}
# 2024-09-23 15:30:18,498 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:30:20,084 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['FP1'], 'bad_by_correlation': ['C4', 'FP2', 'T4', 'T5', 'A1', 'FZ', 'C3', 'T3', 'FP1'], 'bad_by_SNR': ['FP1'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'FP1', 'CZ', 'FP2'], 'bad_all': ['C4', 'CZ', 'T4', 'FP2', 'F8', 'T5', 'A1', 'FZ', 'FP1', 'C3', 'T3']}
# 2024-09-23 15:30:20,084 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:30:26,252 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['FZ'], 'bad_by_correlation': [], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6', 'CZ'], 'bad_all': ['CZ', 'FZ', 'F8', 'T6']}
# 2024-09-23 15:30:27,559 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP2'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'T4', 'A1', 'FZ', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'T4', 'FP2', 'A1', 'FZ', 'C3', 'T3']}
# 2024-09-23 15:30:27,594 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:30:29,089 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP2'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'T4', 'A1', 'FZ', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'F8'], 'bad_all': ['C4', 'A2', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'C3', 'T3']}
# 2024-09-23 15:30:29,119 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:30:30,696 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP2'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'T4', 'FP2', 'A1', 'FZ', 'F7', 'C3', 'T3', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'C3', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:30:30,731 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:30:32,664 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP2'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'FP2', 'T4', 'A1', 'FZ', 'F7', 'C3', 'T3', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'C3', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:30:32,665 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:30:39,558 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A1', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['A1', 'T6', 'F8', 'CZ']}
# 2024-09-23 15:30:40,740 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'FZ', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'F8'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'A1', 'FZ', 'C3', 'T3']}
# 2024-09-23 15:30:40,766 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:30:41,959 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'FP2', 'F8', 'T4'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6', 'FP1']}
# 2024-09-23 15:30:41,988 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:30:43,661 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'F8', 'T4', 'FP2'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6', 'FP1']}
# 2024-09-23 15:30:43,662 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:30:49,452 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'F8'], 'bad_all': ['C4', 'T3', 'F8']}
# 2024-09-23 15:30:50,868 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'T5', 'A1', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'F8'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'C3', 'T3']}
# 2024-09-23 15:30:50,900 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:30:52,496 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'FP2', 'T5', 'A1', 'F7', 'C3', 'T3', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'F8', 'T5', 'A1', 'F7', 'C3', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:30:52,528 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:30:54,257 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'FP2', 'T4', 'T5', 'A1', 'F7', 'C3', 'T3', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'C3', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'T5', 'A1', 'F7', 'C3', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:30:54,257 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:31:01,191 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': [], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T4', 'C4', 'F8', 'T6'], 'bad_all': ['C4', 'F8', 'T6', 'T4']}
# 2024-09-23 15:31:02,621 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T3', 'CZ', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T3', 'T6']}
# 2024-09-23 15:31:02,648 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:31:04,153 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'CZ', 'T4', 'F7', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:31:04,179 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:31:05,693 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['T4'], 'bad_by_correlation': ['C4', 'CZ', 'T4', 'F7', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:31:05,694 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:31:11,592 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T6', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['CZ', 'A2', 'F8', 'T6']}
# 2024-09-23 15:31:13,359 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T3', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['A2', 'T3', 'CZ', 'F8']}
# 2024-09-23 15:31:13,389 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:31:14,983 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'F7', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T4'], 'bad_all': ['A2', 'CZ', 'T4', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:31:15,015 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:31:16,741 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'F7', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T4'], 'bad_all': ['A2', 'CZ', 'T4', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:31:16,742 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:31:23,721 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C3', 'C4', 'FZ', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6'], 'bad_all': ['C4', 'CZ', 'FZ', 'C3', 'T6']}
# 2024-09-23 15:31:27,233 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A1', 'CZ'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['A1', 'T6', 'F8', 'CZ']}
# 2024-09-23 15:31:28,682 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A1', 'C3', 'FP1', 'T4'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'C3', 'FP1', 'T6']}
# 2024-09-23 15:31:28,709 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:31:30,005 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'T4', 'A1', 'C3', 'FP1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'A2', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'F8', 'A1', 'C3', 'FP1', 'T6']}
# 2024-09-23 15:31:30,031 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:31:31,399 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'T4', 'A1', 'FZ', 'C3', 'FP1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'A2', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'F8', 'A1', 'FZ', 'C3', 'FP1', 'T6']}
# 2024-09-23 15:31:31,424 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:31:32,833 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'T4', 'A1', 'FZ', 'C3', 'FP1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'A2', 'F8', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'F8', 'A1', 'FZ', 'C3', 'FP1', 'T6']}
# 2024-09-23 15:31:32,834 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:31:38,628 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['A1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A1', 'CZ'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['A1', 'T6', 'F8', 'CZ']}
# 2024-09-23 15:31:39,911 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['A1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'F8', 'A1', 'F7', 'C3'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['T3'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'A1', 'F7', 'C3', 'T3']}
# 2024-09-23 15:31:39,942 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:31:41,430 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['A1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'F7', 'FZ', 'C3', 'FP1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['T3', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'F7', 'FZ', 'C3', 'FP1', 'T3', 'T6']}
# 2024-09-23 15:31:41,460 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:31:43,334 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['A1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'F8', 'A1', 'F7', 'FZ', 'C3', 'FP1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['T3', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'F8', 'A1', 'F7', 'FZ', 'C3', 'FP1', 'T3', 'T6']}
# 2024-09-23 15:31:43,335 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:31:50,450 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6'], 'bad_all': ['FZ', 'T6']}
# 2024-09-23 15:31:51,905 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A1', 'FZ', 'T3', 'FP2'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['FP2', 'F8', 'A1', 'FZ', 'T3', 'T6']}
# 2024-09-23 15:31:51,932 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:31:53,325 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FP2', 'A1', 'FZ', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['FP2', 'F8', 'A1', 'FZ', 'T3', 'T6']}
# 2024-09-23 15:31:53,352 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:31:54,752 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FP2', 'A1', 'FZ', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'FP1', 'T6'], 'bad_all': ['FP2', 'F8', 'A1', 'FZ', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:31:54,779 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:31:56,235 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FP2', 'A1', 'FZ', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'FP1', 'T6'], 'bad_all': ['FP2', 'F8', 'A1', 'FZ', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:31:56,236 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:32:02,195 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['FZ'], 'bad_by_correlation': ['T6', 'FZ'], 'bad_by_SNR': ['FZ'], 'bad_by_dropout': [], 'bad_by_ransac': ['CZ'], 'bad_all': ['CZ', 'FZ', 'T6']}
# 2024-09-23 15:32:03,258 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:32:03,289 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:32:04,809 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'O2', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'O2', 'F8', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:32:04,845 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:32:06,697 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['FZ'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'O2', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': ['FZ'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'O2', 'F8', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:32:06,698 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:32:13,475 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C3', 'FZ', 'F7'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6'], 'bad_all': ['FZ', 'C3', 'T6', 'F7']}
# 2024-09-23 15:32:14,603 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'T4', 'F7', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A1', 'F8'], 'bad_all': ['C4', 'A2', 'T4', 'F8', 'A1', 'F7', 'FP1', 'C3', 'T3']}
# 2024-09-23 15:32:14,629 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:32:15,772 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'F7', 'FZ', 'C3', 'T3', 'T6', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A1', 'F8', 'FP2'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'F7', 'FZ', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:32:15,810 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:32:17,385 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'F7', 'FZ', 'C3', 'T3', 'T6', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A1', 'F8', 'FP2'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'F7', 'FZ', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:32:17,385 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:32:22,947 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['F7', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['F7', 'T6', 'F8', 'CZ']}
# 2024-09-23 15:32:24,335 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['A2', 'CZ', 'T4', 'F8', 'A1', 'FP1', 'C3', 'T3']}
# 2024-09-23 15:32:24,367 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:32:25,968 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1', 'T4'], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'C3', 'T3', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['A2', 'CZ', 'T4', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:32:26,000 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:32:27,521 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1', 'T4'], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'C3', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6', 'FP2'], 'bad_all': ['A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:32:27,552 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:32:29,380 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1', 'T4'], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'C3', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6', 'FP2'], 'bad_all': ['A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:32:29,380 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:32:36,141 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['F7'], 'bad_by_hf_noise': ['F7'], 'bad_by_correlation': ['T4', 'A2', 'C3', 'C4', 'A1', 'F7'], 'bad_by_SNR': ['F7'], 'bad_by_dropout': [], 'bad_by_ransac': ['T3', 'F8'], 'bad_all': ['C4', 'A2', 'T4', 'F8', 'A1', 'F7', 'C3', 'T3']}
# 2024-09-23 15:32:40,271 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T6', 'FZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'CZ'], 'bad_all': ['CZ', 'FZ', 'F8', 'T6']}
# 2024-09-23 15:32:41,402 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['A2', 'FP2', 'T4', 'F8', 'A1', 'FZ', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:32:41,433 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:32:42,581 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'FP2', 'T4', 'F8', 'A1', 'FZ', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['A2', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:32:42,609 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:32:43,784 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['A2', 'FP2', 'T4', 'F8', 'A1', 'FZ', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:32:43,784 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:32:49,325 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C3', 'T3', 'FZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6', 'CZ'], 'bad_all': ['CZ', 'FZ', 'C3', 'T3', 'T6']}
# 2024-09-23 15:32:50,478 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T4', 'FP2', 'F8', 'T5', 'A1', 'FZ', 'C3', 'T3', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['A2', 'FP2', 'T4', 'F8', 'T5', 'A1', 'FZ', 'C3', 'T3', 'FP1']}
# 2024-09-23 15:32:50,510 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:32:52,104 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'FP2', 'T4', 'F8', 'T5', 'A1', 'FZ', 'C3', 'T3', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F7', 'T6'], 'bad_all': ['A2', 'T4', 'FP2', 'F8', 'T5', 'A1', 'FZ', 'F7', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:32:52,136 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:32:54,109 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T4', 'FP2', 'F8', 'T5', 'A1', 'FZ', 'C3', 'T3', 'FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T4', 'F8', 'A1', 'F7', 'T6'], 'bad_all': ['A2', 'FP2', 'T4', 'F8', 'T5', 'A1', 'FZ', 'F7', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:32:54,109 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:33:01,462 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A2'], 'bad_by_correlation': [], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6'], 'bad_all': ['A2', 'T6']}
# 2024-09-23 15:33:05,670 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': [], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': []}
# 2024-09-23 15:33:09,497 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FZ', 'FP1', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6', 'FP2'], 'bad_all': ['CZ', 'FP2', 'FZ', 'FP1', 'T6']}
# 2024-09-23 15:33:10,545 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'T5', 'A1', 'T3', 'FP1', 'O1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['C3'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'T5', 'A1', 'T3', 'FP1', 'C3', 'O1']}
# 2024-09-23 15:33:10,572 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:33:11,937 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'O2', 'T5', 'A1', 'T3', 'FP1', 'O1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['F7', 'C3'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'O2', 'T5', 'A1', 'F7', 'T3', 'FP1', 'C3', 'O1']}
# 2024-09-23 15:33:11,965 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:33:13,796 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1', 'FP1'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'O2', 'T5', 'A1', 'T3', 'FP1', 'O1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['F7', 'C3'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'O2', 'T5', 'A1', 'F7', 'FP1', 'T3', 'C3', 'O1']}
# 2024-09-23 15:33:13,796 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:33:19,746 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['FP1'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6'], 'bad_all': ['A1', 'FP1', 'T6']}
# 2024-09-23 15:33:21,441 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['A2', 'CZ', 'T4', 'F8', 'A1', 'T3']}
# 2024-09-23 15:33:21,498 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:33:23,209 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'FZ', 'T3', 'FP1', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['A2', 'CZ', 'T4', 'F8', 'A1', 'FZ', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:33:23,262 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:33:24,583 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['A2', 'CZ', 'T4', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'T3', 'T6']}
# 2024-09-23 15:33:24,630 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:33:26,131 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['A2', 'CZ', 'T4', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'T3', 'T6']}
# 2024-09-23 15:33:26,131 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:33:33,114 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': [], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['CZ'], 'bad_all': ['CZ']}
# 2024-09-23 15:33:34,492 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A1', 'C3', 'T3', 'T4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['T4', 'F8', 'A1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:33:34,520 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:33:35,912 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A1', 'C3', 'T4', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:33:35,949 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:33:37,327 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T4', 'A1', 'FZ', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6', 'T4'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'FZ', 'C3', 'T3', 'T6']}
# 2024-09-23 15:33:37,356 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:33:38,733 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'T4', 'A1', 'FZ', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'F8', 'T6', 'T4'], 'bad_all': ['A2', 'T4', 'F8', 'A1', 'FZ', 'C3', 'T3', 'T6']}
# 2024-09-23 15:33:38,734 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:33:44,638 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['T3'], 'bad_by_correlation': ['C3', 'T3'], 'bad_by_SNR': ['T3'], 'bad_by_dropout': [], 'bad_by_ransac': ['T6', 'CZ'], 'bad_all': ['CZ', 'C3', 'T3', 'T6']}
# 2024-09-23 15:33:45,760 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['T3'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'F7', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'F7', 'T3', 'C3']}
# 2024-09-23 15:33:45,818 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:33:47,438 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['T3'], 'bad_by_hf_noise': ['T3', 'T4'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'T5', 'A1', 'F7', 'FZ', 'C3', 'T3'], 'bad_by_SNR': ['T3'], 'bad_by_dropout': [], 'bad_by_ransac': ['FP1', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'T5', 'A1', 'F7', 'FZ', 'T3', 'C3', 'FP1', 'T6']}
# 2024-09-23 15:33:47,477 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:33:49,191 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['T3'], 'bad_by_hf_noise': ['T3', 'T4'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'F8', 'T5', 'A1', 'F7', 'FZ', 'C3', 'T3'], 'bad_by_SNR': ['T3'], 'bad_by_dropout': [], 'bad_by_ransac': ['O2', 'A1', 'FP1', 'T6', 'O1'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'O2', 'F8', 'T5', 'A1', 'F7', 'FZ', 'T3', 'C3', 'FP1', 'T6', 'O1']}
# 2024-09-23 15:33:52,424 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T3', 'FZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['FP2'], 'bad_all': ['C4', 'FZ', 'T3', 'FP2']}
# 2024-09-23 15:33:56,505 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['F7'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6', 'CZ'], 'bad_all': ['CZ', 'F8', 'A1', 'F7', 'T6']}
# 2024-09-23 15:33:57,645 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1', 'FP2'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'T4', 'FP2', 'F8', 'A1', 'F7', 'C3', 'T3', 'FP1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'FP2', 'F8', 'A1', 'F7', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:33:57,677 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:33:58,939 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1', 'FP2'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'FP2', 'T4', 'F8', 'A1', 'F7', 'C3', 'T3', 'FP1', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'FZ', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'FP2', 'F8', 'A1', 'F7', 'FZ', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:33:58,974 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:34:00,536 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1', 'FP2'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A2', 'T4', 'FP2', 'F8', 'A1', 'F7', 'C3', 'T3', 'FP1', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['C4', 'T4', 'F8', 'FZ', 'T6'], 'bad_all': ['C4', 'A2', 'T4', 'FP2', 'F8', 'A1', 'F7', 'FZ', 'FP1', 'C3', 'T3', 'T6']}
# 2024-09-23 15:34:00,538 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:34:06,169 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['A1', 'FZ', 'F7', 'FP1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': ['T6', 'FP2'], 'bad_all': ['FP2', 'A1', 'FZ', 'F7', 'FP1', 'T6']}
# 2024-09-23 15:34:07,226 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'C3', 'T3', 'FP1'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'C3', 'T3', 'FP1']}
# 2024-09-23 15:34:07,267 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:34:08,867 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['A1'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'F8', 'A1', 'FZ', 'C3', 'T3', 'FP1', 'T6'], 'bad_by_SNR': ['A1'], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'CZ', 'FP2', 'T4', 'F8', 'A1', 'FZ', 'C3', 'T3', 'FP1', 'T6']}
# ...
# 2024-09-23 15:39:07,829 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:39:09,423 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'C3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6', 'T4'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'A1', 'FZ', 'F7', 'C3', 'T6']}
# 2024-09-23 15:39:09,423 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:39:16,343 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'FZ', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C3'], 'bad_all': ['C4', 'FZ', 'C3', 'CZ']}
# 2024-09-23 15:39:20,252 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T6', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C3', 'F8'], 'bad_all': ['CZ', 'C3', 'T6', 'F8']}
# 2024-09-23 15:39:21,804 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'CZ', 'T4', 'F8', 'A1', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'A1', 'T6']}
# 2024-09-23 15:39:21,831 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:39:23,335 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'FZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'CZ', 'T4', 'F8', 'A1', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'A1', 'FZ', 'T6']}
# 2024-09-23 15:39:23,361 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:39:24,873 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'FZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A2', 'CZ', 'T4', 'F8', 'A1', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'A1', 'FZ', 'T6']}
# 2024-09-23 15:39:24,874 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:39:30,847 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T6', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['CZ', 'F8', 'T6']}
# 2024-09-23 15:39:32,507 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['F7'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T3', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['C4', 'CZ', 'F8', 'F7', 'T3']}
# 2024-09-23 15:39:32,542 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:39:34,320 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['F7'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T6', 'T3', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'CZ'], 'bad_all': ['C4', 'CZ', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:39:34,353 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:39:36,098 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['F7'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'CZ', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'CZ'], 'bad_all': ['C4', 'CZ', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:39:36,099 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:39:43,214 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T6', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C3'], 'bad_all': ['CZ', 'C3', 'T6']}
# 2024-09-23 15:39:44,785 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A1', 'F8', 'T6', 'T4'], 'bad_all': ['C4', 'T4', 'F8', 'A1', 'T6']}
# 2024-09-23 15:39:44,812 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:39:46,420 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A1', 'F8', 'T6', 'T4'], 'bad_all': ['C4', 'T4', 'F8', 'A1', 'T6']}
# 2024-09-23 15:39:46,478 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:39:48,094 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['A1', 'F8', 'T6', 'T4'], 'bad_all': ['C4', 'T4', 'F8', 'A1', 'T6']}
# 2024-09-23 15:39:48,095 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:39:54,152 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T6', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['FP2'], 'bad_all': ['CZ', 'T6', 'FP2']}
# 2024-09-23 15:39:55,813 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['F7'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T3', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T4'], 'bad_all': ['C4', 'CZ', 'T4', 'F8', 'F7', 'T3']}
# 2024-09-23 15:39:55,845 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:39:57,629 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['F7'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T3', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T3', 'T6', 'T4'], 'bad_all': ['C4', 'CZ', 'T4', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:39:57,670 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:39:59,317 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['F7'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T6', 'T3', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T4', 'T6', 'T3'], 'bad_all': ['C4', 'CZ', 'T4', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:39:59,318 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:40:06,238 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['T4', 'C4'], 'bad_by_correlation': ['C4', 'A1', 'T6', 'FZ', 'CZ'], 'bad_by_SNR': ['C4'], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'CZ', 'T4', 'A1', 'FZ', 'T6']}
# 2024-09-23 15:40:10,171 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C3', 'T6', 'CZ'], 'bad_all': ['CZ', 'FZ', 'C3', 'T6']}
# 2024-09-23 15:40:14,055 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['CZ'], 'bad_by_correlation': ['A1', 'FZ', 'F7', 'CZ'], 'bad_by_SNR': ['CZ'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['CZ', 'F8', 'A1', 'FZ', 'F7', 'T6']}
# 2024-09-23 15:40:15,003 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'T5', 'A1', 'FZ', 'F7', 'C3', 'T3'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'T5', 'A1', 'FZ', 'F7', 'C3', 'T3']}
# 2024-09-23 15:40:15,028 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:40:16,336 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['CZ'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'T5', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6'], 'bad_by_SNR': ['CZ'], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'T5', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6']}
# 2024-09-23 15:40:16,362 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:40:17,842 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['CZ'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'T5', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6'], 'bad_by_SNR': ['CZ'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6']}
# 2024-09-23 15:40:17,868 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:40:19,271 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['CZ'], 'bad_by_hf_noise': ['CZ'], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'T5', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6'], 'bad_by_SNR': ['CZ'], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'T6'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'FZ', 'F7', 'C3', 'T3', 'T6']}
# 2024-09-23 15:40:19,271 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:40:24,892 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP2'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A2', 'A1', 'T6', 'FZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['FP1'], 'bad_all': ['A2', 'FP2', 'A1', 'FZ', 'FP1', 'T6']}
# 2024-09-23 15:40:28,908 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'O2', 'F7'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8', 'CZ'], 'bad_all': ['C4', 'CZ', 'O2', 'F8', 'F7']}
# 2024-09-23 15:40:30,216 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T4', 'O2', 'F7', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['C4', 'T4', 'O2', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:40:30,243 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:40:31,507 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T4', 'O2', 'F7', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['C4', 'T4', 'O2', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:40:31,537 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:40:32,799 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'T4', 'O2', 'F7', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['F8'], 'bad_all': ['C4', 'T4', 'O2', 'F8', 'F7', 'T3', 'T6']}
# 2024-09-23 15:40:32,800 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:40:38,390 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FZ', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T6'], 'bad_all': ['FZ', 'T6', 'CZ']}
# 2024-09-23 15:40:39,741 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'A1', 'FZ', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C3'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'A1', 'FZ', 'T3', 'C3', 'T6']}
# 2024-09-23 15:40:39,776 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:40:41,342 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'A1', 'FZ', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C3', 'F8'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'A1', 'FZ', 'T3', 'C3', 'T6']}
# 2024-09-23 15:40:41,376 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:40:43,027 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['FP2', 'C3', 'F8'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'T3', 'T6', 'C3']}
# 2024-09-23 15:40:43,057 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:40:45,032 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': ['FP1'], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'A1', 'FZ', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['C3', 'F8', 'FP2'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'A1', 'FZ', 'F7', 'FP1', 'T3', 'T6', 'C3']}
# 2024-09-23 15:40:45,032 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:40:51,470 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['A1', 'T6', 'F7', 'CZ'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['A1', 'F7', 'CZ', 'T6']}
# 2024-09-23 15:40:52,458 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'F7', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'F7', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:40:52,492 - pyprep.reference - INFO - Iterations: 1
# 2024-09-23 15:40:53,707 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'F7', 'FZ', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'F7', 'FZ', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:40:53,746 - pyprep.reference - INFO - Iterations: 2
# 2024-09-23 15:40:54,952 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'F7', 'FZ', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['FP2'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'T5', 'A1', 'F7', 'FZ', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:40:54,986 - pyprep.reference - INFO - Iterations: 3
# 2024-09-23 15:40:56,231 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['C4', 'A2', 'CZ', 'T4', 'F8', 'T5', 'A1', 'F7', 'FZ', 'T3', 'FP1', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['FP2'], 'bad_all': ['C4', 'A2', 'CZ', 'T4', 'FP2', 'F8', 'T5', 'A1', 'F7', 'FZ', 'T3', 'FP1', 'T6']}
# 2024-09-23 15:40:56,232 - pyprep.reference - INFO - Robust reference done
# 2024-09-23 15:41:01,603 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['T4', 'A1', 'T3', 'T6'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['A1', 'T3', 'T6', 'T4']}

# %%
len(stressed_data)
# Out:
# 27

# %%
len(no_stressed_data)
# Out:
# 27

# %%
stressed_data[0].shape
# Out:
# (719, 4, 250)

# %%
no_stressed_data[1].shape
# Out:
# (599, 4, 250)

# %%
channels_names=['FP1','FP2','F7','F8']

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K
# Out:
# 2024-09-23 15:41:31,966 - numexpr.utils - INFO - NumExpr defaulting to 16 threads.

# %%
def EEGNet(nb_classes, Chans = 64, Samples = 128, 
             dropoutRate = 0.5, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)

# %%
no_stressed = np.vstack(no_stressed_data)
stressed = np.vstack(stressed_data)

# %%
no_stressed.shape
# Out:
# (16173, 4, 250)

# %%
stressed.shape
# Out:
# (19413, 4, 250)

# %%
no_stressed_labels = np.zeros(16173)
stressed_labels = np.ones(19413)

# %%
data_list = np.concatenate((no_stressed, stressed), axis=0)

label_list = np.concatenate((no_stressed_labels, stressed_labels), axis=0)

print(data_list.shape)  
print(label_list.shape)
# Out:
# (35586, 4, 250)
# (35586,)

# %%
no_stressed = no_stressed.reshape((16173, 4, 250, 1))
stressed = stressed.reshape((19413, 4, 250, 1))


data_list = np.concatenate((no_stressed, stressed), axis=0)
label_list = np.concatenate((no_stressed_labels, stressed_labels), axis=0)

# %%
# Define the EEGNet model
nb_classes = 2  # Example for binary classification: Stressed vs Not Stressed
model = EEGNet(nb_classes=nb_classes, Chans=4, Samples=250)

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# c:\Users\itsay\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.utils import to_categorical

# One-hot encode the labels
label_list = to_categorical(label_list, num_classes=nb_classes)

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_list, label_list, test_size=0.2, random_state=42)

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 890/890 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.6283 - loss: 0.6200 - val_accuracy: 0.5927 - val_loss: 0.7084
# Epoch 2/100
# 890/890 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.6597 - loss: 0.5818 - val_accuracy: 0.6510 - val_loss: 0.5948
# Epoch 3/100
# 890/890 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.6606 - loss: 0.5846 - val_accuracy: 0.6762 - val_loss: 0.6443
# Epoch 4/100
# 890/890 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.6671 - loss: 0.5769 - val_accuracy: 0.6321 - val_loss: 0.6342
# Epoch 5/100
# 890/890 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.6734 - loss: 0.5742 - val_accuracy: 0.6123 - val_loss: 0.7047
# Epoch 6/100
# 890/890 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.6759 - loss: 0.5696 - val_accuracy: 0.6346 - val_loss: 0.6622
# Epoch 7/100
# 890/890 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.